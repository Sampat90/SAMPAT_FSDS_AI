# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load sample data set
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(style="darkgrid")

# %%
#1. Scatter Plot: Total Bill vs Tip, with hue and size

sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", palette="deep")
plt.title("Scatter Plot: Total Bill vs Tip by Time and Size")
plt.show()

# %%
# 2. Line Plot: Total Bill by Party Size, split by Sex

sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o")
plt.title("Line Plot: Total Bill by Party Size and Sex")
plt.show()
# Out:
# C:\Users\dassa\AppData\Local\Temp\ipykernel_22368\2528697441.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 # 2. Line Plot: Total Bill by Party Size, split by Sex
#       3 sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o")
# ----> 4 plt.title("Line Plot: Total Bill by Party Size and Sex")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
	
# 3. Bar Plot: Average Total Bill by Day, split by Sex

sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted")
plt.title("Bar Plot: Average Total Bill by Day and Sex")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # 3. Bar Plot: Average Total Bill by Day, split by Sex
#       3 sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted")
# ----> 4 plt.title("Bar Plot: Average Total Bill by Day and Sex")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# 4. Box Plot: Total Bill by Day, split by Time

sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2")
plt.title("Box Plot: Tips by Day and Smoker Status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 # 4. Box Plot: Total Bill by Day, split by Time
#       3 sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2")
# ----> 4 plt.title("Box Plot: Tips by Day and Smoker Status")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
## 5. Violin Plot: Total Bill by Day, split by Time

sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel")
plt.title("Violin Plot: Total Bill by Day and Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 ## 5. Violin Plot: Total Bill by Day, split by Time
#       3 sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel")
# ----> 4 plt.title("Violin Plot: Total Bill by Day and Time")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
	
## 5. Violin Plot: Total Bill by Day, split by Time

sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel")
plt.title("Violin Plot: Total Bill by Day and Time")
plt.show()

# %%
	
# 6. Count Plot: Orders by Day, split by Smoker

sns.countplot(data=tips, x="day", hue="smoker", palette="dark")
plt.title("Count Plot: Orders by Day and Smoker Status")
plt.show()

# %%
# 7. Regression Plot: Total Bill vs Tip with regression line

sns.regplot(data=tips, x="total_bill", y="tip", scatter_kws={"s": 50}, line_kws={"color": "red"})
plt.title("Regression Plot: Total Bill vs Tip")
plt.show()

# %%
#8. Histogram (Distribution Plot): Total Bill with KDE

sns.histplot(data=tips, x="total_bill", kde=True, bins=20, color="blue")
plt.title("Histogram: Distribution of Total Bill")
plt.show()

# %%
	
#9. Pair Plot: Relationships between numerical variables

sns.pairplot(tips, hue="sex", vars=["total_bill", "tip", "size"], palette="husl")
plt.suptitle("Pair Plot: Numerical Variables by Sex", y=1.02)
plt.show()

# %%
	
# 10. Catplot (Point Plot): Tip by Day and Sex

sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="point", palette="bright")
plt.title("Catplot (Point): Tips by Day and Sex")
plt.show()

# %%
# 11. Joint Plot: Total Bill vs Tip with marginal distributions
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", palette="coolwarm")
plt.suptitle("Joint Plot: Total Bill vs Tip by Smoker", y=1.02)
plt.show()

# %%
	
# 12. FacetGrid: Total Bill by Day, faceted by Time and Smoker
g = sns.FacetGrid(tips, col="time", row="smoker", margin_titles=True)
g.map(sns.histplot, "total_bill", bins=15)
g.fig.suptitle("FacetGrid: Total Bill by Time and Smoker", y=1.02)
plt.show()

# %%
	
# 13. Strip Plot: Tips by Day, colored by Sex
plt.figure(figsize=(8, 6))
sns.stripplot(data=tips, x="day", y="tip", hue="sex", palette="Set1", jitter=True)
plt.title("Strip Plot: Tips by Day and Sex")
plt.show()

# %%
# 14. KDE Plot: Total Bill density by Sex
plt.figure(figsize=(8, 6))
sns.kdeplot(data=tips, x="total_bill", hue="sex", fill=True, palette="tab10")
plt.title("KDE Plot: Total Bill Density by Sex")
plt.show()

# %%
# !pip install streamlit
# Out:
# Access is denied.

# %%
# !pip install --user streamlit
# Out:
# Access is denied.

# %%
streamlit run web.py
# Out:
#   Cell In[45], line 1
#     streamlit run web.py
#               ^
# SyntaxError: invalid syntax

# %%
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style
sns.set(style="whitegrid")

# Load the tips dataset
tips = sns.load_dataset('tips')

# Streamlit app
st.title("Comprehensive Tips Dataset Visualizations")
st.write("This app displays a variety of Seaborn plots created by prakash senapati exploring the Tips dataset, which includes data on restaurant bills and tips.")

# Function to create and display a plot
def display_plot(title, plot_func):
    st.subheader(title)
    fig, ax = plt.subplots(figsize=(8, 6))
    plot_func(ax)
    st.pyplot(fig)
    plt.close(fig)  # Close the figure to free memory

# Plot definitions
def scatter_plot(ax):
    sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", palette="deep", ax=ax)
    ax.set_title("Scatter Plot: Total Bill vs Tip by Time and Size")

def line_plot(ax):
    sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o", ax=ax)
    ax.set_title("Line Plot: Total Bill by Party Size and Sex")

def bar_plot(ax):
    sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted", ax=ax)
    ax.set_title("Bar Plot: Average Total Bill by Day and Sex")

def box_plot(ax):
    sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2", ax=ax)
    ax.set_title("Box Plot: Tips by Day and Smoker Status")

def violin_plot(ax):
    sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel", ax=ax)
    ax.set_title("Violin Plot: Total Bill by Day and Time")

def count_plot(ax):
    sns.countplot(data=tips, x="day", hue="smoker", palette="dark", ax=ax)
    ax.set_title("Count Plot: Orders by Day and Smoker Status")

def reg_plot(ax):
    sns.regplot(data=tips, x="total_bill", y="tip", scatter_kws={"s": 50}, line_kws={"color": "red"}, ax=ax)
    ax.set_title("Regression Plot: Total Bill vs Tip")

def hist_plot(ax):
    sns.histplot(data=tips, x="total_bill", kde=True, bins=20, color="blue", ax=ax)
    ax.set_title("Histogram: Distribution of Total Bill")

def strip_plot(ax):
    sns.stripplot(data=tips, x="day", y="tip", hue="sex", palette="Set1", jitter=True, ax=ax)
    ax.set_title("Strip Plot: Tips by Day and Sex")

def swarm_plot(ax):
    sns.swarmplot(data=tips, x="day", y="tip", hue="smoker", palette="Set3", ax=ax)
    ax.set_title("Swarm Plot: Tips by Day and Smoker Status")

def kde_plot(ax):
    sns.kdeplot(data=tips, x="total_bill", hue="sex", fill=True, palette="tab10", ax=ax)
    ax.set_title("KDE Plot: Total Bill Density by Sex")

# Special cases that need custom handling
st.subheader("Pair Plot: Numerical Variables by Sex")
pair_fig = sns.pairplot(tips, hue="sex", vars=["total_bill", "tip", "size"], palette="husl")
pair_fig.fig.suptitle("Pair Plot: Numerical Variables by Sex", y=1.02)
st.pyplot(pair_fig.fig)
plt.close(pair_fig.fig)

st.subheader("Joint Plot: Total Bill vs Tip by Smoker")
joint_fig = sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", palette="coolwarm")
joint_fig.fig.suptitle("Joint Plot: Total Bill vs Tip by Smoker", y=1.02)
st.pyplot(joint_fig.fig)
plt.close(joint_fig.fig)

st.subheader("FacetGrid: Total Bill by Time and Smoker")
g = sns.FacetGrid(tips, col="time", row="smoker", margin_titles=True)
g.map(sns.histplot, "total_bill", bins=15)
g.fig.suptitle("FacetGrid: Total Bill by Time and Smoker", y=1.02)
st.pyplot(g.fig)
plt.close(g.fig)

st.subheader("Catplot (Point): Tips by Day and Sex")
cat_fig = sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="point", palette="bright")
cat_fig.fig.suptitle("Catplot (Point): Tips by Day and Sex", y=1.02)
st.pyplot(cat_fig.fig)
plt.close(cat_fig.fig)

# Display all standard plots
display_plot("Scatter Plot", scatter_plot)
display_plot("Line Plot", line_plot)
display_plot("Bar Plot", bar_plot)
display_plot("Box Plot", box_plot)
display_plot("Violin Plot", violin_plot)
display_plot("Count Plot", count_plot)
display_plot("Regression Plot", reg_plot)
display_plot("Histogram", hist_plot)
display_plot("Strip Plot", strip_plot)
display_plot("Swarm Plot", swarm_plot)
display_plot("KDE Plot", kde_plot)

st.write("All Seaborn plots for the Tips dataset have been generated!")
# Out:
# 2025-09-07 14:10:05.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:05.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:05.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:05.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:05.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:05.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:09.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:11.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:11.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:11.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:11.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:11.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:12.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:12.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:12.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:12.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:14.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:15.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:15.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:15.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:15.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:16.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:17.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:17.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:17.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:17.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:17.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:18.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:18.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:18.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:18.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\dassa\AppData\Local\Temp\ipykernel_22368\279624297.py:29: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o", ax=ax)
# 2025-09-07 14:10:18.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:19.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:19.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:19.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:19.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:20.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:21.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:21.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:21.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:21.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:21.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:22.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:22.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:22.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:22.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:22.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:23.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:23.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:23.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:23.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:23.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:24.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:24.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:24.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:24.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:24.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:25.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:25.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:25.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:25.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:25.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:26.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:27.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:28.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:28.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:28.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:28.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:28.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:29.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:29.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:29.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-07 14:10:29.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
